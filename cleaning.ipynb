# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("aws_supply_chain_orders_raw.csv")

# %%
df
# Out:
#      order_id warehouse region  product  order_qty  \
# 0    ORD-1000      WH-C   West   Router         42
# 1    ORD-1001      WH-A   West   Laptop         30
# 2    ORD-1002      WH-C  South   Switch         19
# 3    ORD-1003      WH-C  North   Server         17
# 4    ORD-1004      WH-A   East   Laptop         19
# ..        ...       ...    ...      ...        ...
# 150  ORD-1101      WH-C  South   Router         29
# 151  ORD-1082      WH-B  North   Laptop         12
# 152  ORD-1031      WH-C  South   Server         37
# 153  ORD-1064      WH-B  South   Laptop         45
# 154  ORD-1067      WH-B   West  Storage         24
#
#                      order_date               delivery_date  \
# 0    2026-02-16 06:22:56.185879  2026-03-24 06:22:56.186200
# 1    2026-02-25 06:22:56.185905  2026-03-15 06:22:56.186205
# 2    2026-03-13 06:22:56.185910  2026-03-13 06:22:56.186207
# 3    2026-02-14 06:22:56.185913  2026-03-01 06:22:56.186209
# ...

# %%
df.loc[0,"product"]
# Out:
# 'Router'
